# %%
num=int(input())
print("enter number:",num)
if num>0:
    print("positive number")
elif num<0:
    print("negative number")
else:
    print(0)
# Out:
# enter number: 23
# positive number

# %%
num=int(input())
print("enter number:",num)
if num%2==0:
    print("number is even")
else:
    print("odd")
# Out:
# enter number: 44
# number is even

# %%
marks=int(input())
print("enter your marks:",marks)
if marks>=33:
    print("pass")
else:
    print("fail")
# Out:
# enter your marks: 34
# pass

# %%
num1=int(input())
print("enter a number1:-",num1)
num2=int(input())
print("enter a number2:-",num2)
num3=int(input())
print("enter a number3:-",num3)
if num1>num2 and num1>num3:
    print("num1 is largest")
elif num2>num1 and num2>num3:
    print("num2 is largest")
else:
    print("num3 is largest")
# Out:
# enter a number1:- 23
# enter a number2:- 33
# enter a number3:- 67
# num3 is largest

# %%
age=int(input())
print("your age is:",age)
if age>=18:
    print("you are eligible for voting")
else:
    print("you are not eligible for voting!!")
# Out:
# your age is: 34
# you are eligible for voting

# %%
username=input("enter your username:")
print=("enter your username:",username)
password=input()
print("enter your password:",password)
if username=="swati2005":
    if password=="swati123":
       print("login successful")
    else:
       print("invalid password ")
else:
    print("inavlid username")
# Out:
# enter your password: 23
# inavlid username

# %%
pin=int(input())
print("enter your pin:",pin)
withdrawal=float(input())
bal=int(50000)
if pin==123456:
    if bal>=withdrawal:
        print("your withdrawal money:",withdrawal)
        print("your current balance:",bal)
        print("transaction successful!!")
    else:
        print("your withdrawal money:",withdrawal)
        print("your current balance:",bal)
        print("insufficient balance")
else:
    print("invalid pin")
# Out:
# enter your pin: 34567
# invalid pin
