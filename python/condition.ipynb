# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ## conditional statement
#
# ***conditional statements*** are used to control the flow of a program by *executing* different blocks of code based on whether a specific condition is* True* or

# %%
num=input("enter any numbar:")
print(num)
print(type(num))
# Out:
# 34
# <class 'str'>

# %%
num=int(input("enter a number:-"))
print(num)
print(type(num))
# Out:
# 45
# <class 'int'>

# %%
bal=5000
withdrawal=int(input("enter your amount"))
#withdraw=2000
if withdrawl<=bal:
    print("suffient balance")
else:
    print("balance available")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 bal=5000
#       2 withdrawal=int(input("enter your amount"))
#       3 #withdraw=2000
# ----> 4 if withdrawl<=bal:
#       5     print("suffient balance")
#       6 else:
#       7     print("balance available")
#
# NameError: name 'withdrawl' is not defined

# %%
###student fail and pass
max=36
if max<=33:
    print("fail")
else:
    print("pass")
# Out:
# pass

# %%
####traffic signal
signal="red"
if signal=="red":
    print("stop")
elif signal=="yellow":
    print("ready")
else:
    print("go")
# Out:
# stop

# %%
#####voting system
age=int(input("your age:"))
if age>=18:
    print("you can vote")
else:
    print("you cant vote ")
# Out:
# you can vote

# %%
#####delivery offer
totalamount=float(input("enter your amount"))
print(totalamount)
if totalamount>=500:
    print("no delivery charges")
else:
    print("delivery charges added")
    print("add more items for free delivery!!")
# Out:
# 480.0
# delivery charges added
# add more items for free delivery!!

# %%
####grading statement
# marks=float(input("marks of student:"))
# if marks==90 and marks>=90:
#     print("grade :A+")
# elif marks==80 and marks>=80:
#     print("grade:A")
# elif marks==60 and marks<=79:
#     print("grade:B")
# else:
#     print("fail")
# Out:
# fail

# %% [markdown]
# ## nested if
#
# ### syntax:
# if cond:
#
#    if cond:
#
#        ###code
#
#    else:
#
#        #code
#
# else:
#
#     #code

# %%
##### attendance and pass /fail
attendance=80
marks=33
if attendance>=75:
    if marks>=36:
        print("pass")
    else:
        print("fail in exam")
else:
    print("low attendance")

# %%
#####payment
pin=input("enter your pin")
print(pin)
bal=float(input("enter your amount:"))
print(bal)
if pin == "swati234":
    if bal<=50000:
        print("traction done!!")
    else:
        print("transaction failed")
else:
    print("invalid pin")
# Out:
# swati234
# 2000.0
# traction done!!
