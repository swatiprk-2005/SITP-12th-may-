# %% [markdown]
# #### python Function
# * A function is a block of reusable code that performs a specific task.
# Functions help make code shorter, organized, and reusable.
#
#
# Types of Functions in Python
#
# There are mainly 2 types of functions in Python:
#
# 1. Built-in Functions
#
# These functions are already available in Python.
# Some Common Built-in Functions
# * print()
# * len()
# * max()
# * min()
# * sum()
# * type()
# * input()
#
# 2. User-defined Functions
#
# These functions are created by the user using the *def* keyword.
#
# #### syntax:
# def fuction_name():
#     pass
#
#     ####block of code
#     ####pass is a placeholder keyword
#     ####first letter of function should be samll

# %%
def temp():#function defination
    print("hello bbg")
temp() #function call
# Out:
# hello bbg

# %%
def add():
    a=20
    b=23
    print(a+b)
add()
# Out:
# 43

# %%
def add(a,b):
    print(a+b)
add(a=10,b=20)
# Out:
# 30

# %%
def square(a):
    print(a**2)
square(a=12)
# Out:
# 144

# %%
def even(a):
    print(a)
    for x in a:
        if x%2==0:
            print("x is even:",x)
        else:
            print("x is odd:",x)
a1=[1,2,44,56,23]            
even(a=a1)
# Out:
# [1, 2, 44, 56, 23]
# x is odd: 1
# x is even: 2
# x is even: 44
# x is even: 56
# x is odd: 23

# %%
def grade(marks):
    print(marks)
    for x in marks:
        if x>=90:
             print("grade A+")
        elif x>70 or x==80:
                print("grade:A")
        elif x>45 or x==69:
                print("grade:B")
        else:
            print("fail")
marks1=[75,67,99,22]
grade(marks=marks1)
# Out:
# [75, 67, 99, 22]
# grade:A
# grade:B
# grade A+
# fail

# %%
def prime():
    for x in range(1,11):
        if x>1:
            for i in range(2,x):
                if x%i==0:
                   break
                else:
                    print(x)
                
prime()
# Out:
# 3
# 5
# 5
# 5
# 7
# 7
# 7
# 7
# 7
# 9

# %%
print()
