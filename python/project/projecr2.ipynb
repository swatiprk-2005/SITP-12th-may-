# %% [markdown]
# * project on ATM

# %%
class ATM:
    def __init__(self):
        self.d=int(input("enter depoist amount:"))
        self.w=int(input("enter withdrwal amount:"))
        self.balance=20000
    def depoist(self):
        print("your depoisted money:",self.d)
    def withdraw(self):
        print("your withdrwal amount:",self.w)
    def balance1(self):
        if self.w>0:
            if self.d>0:
                self.balance=self.balance+self.d-self.w 
            else:
                self.balance=self.balance-self.w   
        else:
            self.balance=self.balance+self.d
        print("your balance",self.balance)
a=ATM()
a.depoist()
a.withdraw()     
a.balance1()   


#OUTPUT
# Out:
# your depoisted money: 2000
# your withdrwal amount: 200
# your balance 21800

# %% [markdown]
# * BMI calculator for metric units

# %%
class BmiCalculator:
     def __init__(self):
         self.w=float(input("your weight in kgs:"))
         self.h=float(input("your height in cm:"))
         self.c="c"
     def weight(self):
         print("your weight:",self.w)
     def height(self):
         b=self.h/100
         self.c=b*b
         print("your height in m*m :",self.c)
     def bmicheck(self):
         a=self.w/self.c
         print("bmi index is:",a)
         if a<16:
            print("you are severe thickness!! ",a)
         elif a==16 or a<17:
            print("you are moderate thickness!!",a)
         elif  a==17 or a<18.5:
            print("you are mild thickness!!",a)
         elif a==18.5 or a<25:
            print("you are normal!!",a)  
         elif a==25 or a<30:
            print("you are overweight!!",a)  
         elif a==30 or a<35:
            print("you are obese class 1!!",a) 
         elif a==35 or a<=40:
            print("you are obese class 2!!",a) 
         else:
            print("obesityy!!",a)   
obj=BmiCalculator()
obj.weight()
obj.height()
obj.bmicheck() 


# OUTPUT
# Out:
# your weight: 50.0
# your height in m*m : 2.25
# bmi index is: 22.22222222222222
# you are normal!! 22.22222222222222

# %% [markdown]
# * BMI calculator for standard units

# %%
class BmiCalculator:
    def __init__(self):
        self.w=float(input("your weight in kgs:"))
        self.h=float(input("your height in cm:"))
        self.b="b"
        self.c="c"
    def weight(self):
        self.b=self.w*2.2
        print("your weight in pounds",self.b)
    def height(self):
        d=self.h/2.54
        self.c=d*d
        print("your height in inches*inches :",self.c)
    def bmicheck(self):
        a=self.b/self.c
        a=a*703
        print("bmi index is:",a)
        if a<16:
            print("you are severe thickness!! ",a)
        elif a==16 or a<17:
            print("you are moderate thickness!!",a)
        elif  a==17 or a<18.5:
            print("you are mild thickness!!",a)
        elif a==18.5 or a<25:
            print("you are normal!!",a)  
        elif a==25 or a<30:
            print("you are overweight!!",a)  
        elif a==30 or a<35:
            print("you are obese class 1!!",a) 
        elif a==35 or a<=40:
            print("you are obese class 2!!",a) 
        else:
            print("obesityy!!",a)  
obj=BmiCalculator()
obj.weight()
obj.height()
obj.bmicheck()

#OUTPUT
# Out:
# your weight in pounds 110.00000000000001
# your height in inches*inches : 3487.50697501395
# bmi index is: 22.17343235555556
# you are normal!! 22.17343235555556
