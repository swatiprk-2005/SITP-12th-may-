# %% [markdown]
# * project on ATM

# %%
class ATM:
    def __init__(self):
        self.d=int(input("enter deposit amount:"))
        self.w=int(input("enter withdrwal amount:"))
        self.balance=20000
    def deposit(self):
        print("your deposited money:",self.d)
    def withdraw(self):
        print("your withdrwal amount:",self.w)
    def balance1(self):
        if self.w>0:
            if self.d>0:
                self.balance=self.balance+self.d-self.w 
            else:
                self.balance=self.balance-self.w   
        else:
            self.balance=self.balance+self.d
        print("your balance",self.balance)
a=ATM()
a.deposit()
a.withdraw()     
a.balance1() 






















#OUTPUT
# Out:
# your deposited money: 2000
# your withdrwal amount: 200
# your balance 21800

# %% [markdown]
# * BMI calculator for metric units

# %%
class BmiCalculator:
     def __init__(self):
         self.w=float(input("your weight in kgs:"))
         self.h=float(input("your height in cm:"))
         self.c="c"
     def weight(self):
         print("your weight:",self.w)
     def height(self):
         b=self.h/100
         self.c=b*b
         print("your height in m*m :",self.c)
     def bmicheck(self):
         a=self.w/self.c
         print("bmi index is:",a)
         if a<16:
            print("you are severe thinness!! ",a)
         elif 16<a<17:
            print("you are moderate thinness!!",a)
         elif  17<a<18.5:
            print("you are mild thickness!!",a)
         elif 18.5<a<25:
            print("you are normal!!",a)  
         elif 25<a<30:
            print("you are overweight!!",a)  
         elif 30<a<35:
            print("you are obese class 1!!",a) 
         elif 35<a<=40:
            print("you are obese class 2!!",a) 
         else:
            print("obesityy!!",a)   
obj=BmiCalculator()
obj.weight()
obj.height()
obj.bmicheck() 








# OUTPUT
# Out:
# your weight: 47.0
# your height in m*m : 2.7889
# bmi index is: 16.85252249991036
# you are moderate thickness!! 16.85252249991036

# %% [markdown]
# * BMI calculator for standard units

# %%
class BmiCalculator:
    def __init__(self):
        self.w=float(input("your weight in kgs:"))
        self.h=float(input("your height in cm:"))
        self.b="b"
        self.c="c"
    def weight(self):
        self.b=self.w*2.2
        print("your weight in pounds",self.b)
    def height(self):
        d=self.h/2.54
        self.c=d*d
        print("your height in inches*inches :",self.c)
    def bmicheck(self):
        a=self.b/self.c
        a=a*703
        print("bmi index is:",a)
        if a<16:
            print("you are severe thinness!! ",a)
        elif 16<a<17:
            print("you are moderate thinness!!",a)
        elif  17<a<18.5:
            print("you are mild thinness!!",a)
        elif 18.5<a<25:
            print("you are normal!!",a)  
        elif 25<a<30:
            print("you are overweight!!",a)  
        elif 30<a<35:
            print("you are obese class 1!!",a) 
        elif 35<a<=40:
            print("you are obese class 2!!",a) 
        else:
            print("obesityy 3!!",a)  
obj=BmiCalculator()
obj.weight()
obj.height()
obj.bmicheck()


#OUTPUT
# Out:
# your weight in pounds 217.8
# your height in inches*inches : 3675.987351974704
# bmi index is: 41.652319591836736
# obesityy 3!! 41.652319591836736
