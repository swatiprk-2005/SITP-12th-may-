# %% [markdown]
# ### functions used in os module
#
# | Function           | Work                          | Example                       |
# | ------------------ | ----------------------------- | ----------------------------- |
# | os.getcwd()      | Get current working directory | os.getcwd()                 |
# | os.chdir(path)   | Change current directory      | os.chdir("D:/Python")       |
# | os.listdir()     | Show all files and folders    | os.listdir()                |
# | os.mkdir()       | Create one folder             | os.mkdir("Student")         |
# | os.makedirs()    | Create multiple folders       | os.makedirs("Data/Student") |
# | os.rmdir()       | Delete empty folder           | os.rmdir("Student")         |
# | os.removedirs()  | Delete nested empty folders   | os.removedirs("A/B/C")      |
# | os.remove()      | Delete file                   | os.remove("data.txt")       |
# | os.rename()      | Rename file/folder            | os.rename("old","new")      |
# | os.path.exists() | Check file/folder exists      | os.path.exists("Data")      |
# | os.path.isfile() | Check file exists             | os.path.isfile("a.txt")     |
# | os.path.isdir()  | Check folder exists           | os.path.isdir("Student")    |
# | os.path.join()   | Join file paths               | os.path.join("A","B")       |

# %%
import os ##os is a module

# %%
os.getcwd() ##cwd is current working directory
# Out:
# 'c:\\Users\\win-11\\Desktop\\SITP-12th-may-\\os'

# %%
path=r"c:\\Users\\win-11\\Desktop\\data science\\os" #r brgore string tells the python interpreter to treat backslash as a literal(raw) character.
os.listdir(path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 path=r"c:\\Users\\win-11\\Desktop\\data science\\os" #r brgore string tells the python interpreter to treat backslash as a literal(raw) character.
# ----> 2 os.listdir(path)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'c:\\\\Users\\\\win-11\\\\Desktop\\\\data science\\\\os'

# %%
path=r"c:\\Users\\win-11\\Desktop\\data science\\os"
os.listdir(r"c:\\Users\\win-11\\Desktop\\data science\\os")
# Out:
# ['basic.ipynb']

# %%
os.mkdir("hello")

# %%
os.getcwd()
# Out:
# 'c:\\Users\\win-11\\Desktop\\data science\\os'

# %%
os.listdir(r'c:\\Users\\win-11\\Desktop\\data science\\os')
# Out:
# ['basic.ipynb', 'hello']

# %%
###MULTIPLE FOLDERS:
os.makedirs("student\\data\\report")

# %%
os.getcwd()
# Out:
# 'c:\\Users\\win-11\\Desktop\\data science\\os'

# %%
os.listdir(os.getcwd())
# Out:
# ['basic.ipynb', 'hello', 'student']

# %%
os.rmdir("hello") ###remove directory

# %%
os.getcwd()
# Out:
# 'c:\\Users\\win-11\\Desktop\\data science\\os'

# %%
os.listdir(os.getcwd())
# Out:
# ['basic.ipynb', 'student']

# %%
os.rename("student","college") ##to rename a directory (old name,new name)

# %%
os.listdir(os.getcwd())
# Out:
# ['basic.ipynb', 'college']

# %%
os.getcwd()
# Out:
# 'c:\\Users\\win-11\\Desktop\\data science\\os'

# %%
os.chdir(r"C:\Users\win-11\Desktop\data science")

# %%
os.listdir(os.getcwd())
# Out:
# ['deep learning',
#  'flask',
#  'GAN AI',
#  'Git & github',
#  'html & css',
#  'LSTM&GAU',
#  'Machine learning',
#  'matplotlib',
#  'numpy',
#  'os',
#  'pandas',
#  'python',
#  'seaborn']

# %%
path= r"C:\Users\win-11\Desktop\data science"
path1= r"C:\Users\win-11"
path2= r"Desktop\data science"
complete_path=os.path.join(path1,path2)
print(complete_path)
a=os.listdir(complete_path)
print(a)
# Out:
# C:\Users\win-11\Desktop\data science
# ['deep learning', 'flask', 'GAN AI', 'Git & github', 'html & css', 'LSTM&GAU', 'Machine learning', 'matplotlib', 'numpy', 'os', 'pandas', 'python', 'seaborn']

# %%
os.path.isfile(r"C:\Users\win-11\Desktop\data science\os\basic.ipynb")
# Out:
# True

# %%
os.path.isdir(r"C:\Users\win-11\Desktop\data science")
# Out:
# True

# %%
os.path.exists(r"C:\Users\win-11\Desktop\data science\os\basic.ipynb")
# Out:
# True

# %%
os.path.exists(r"C:\Users\win-11\Desktop\data science")
# Out:
# True

# %%
os.path.getsize(r"C:\Users\win-11\Desktop\data science")
# Out:
# 4096

# %%
os.path.getsize(r"C:\Users\win-11\Desktop\data science\os\basic.ipynb")
# Out:
# 9077

# %%
os.mkdir("hi")

# %%
os.rmdir("hi")

# %%
os.rmdir("hello")

# %%
os.mkdir("hello")

# %%
os.chdir(r"C:\Users\win-11\Desktop\data science\os")

# %%
os.makedirs("person\\teacher\\hod")
